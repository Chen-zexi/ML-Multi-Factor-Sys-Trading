# %%
import pandas as pd
import time
from tqdm.notebook import tqdm
import math
import json
import sys
import os
sys.path.append(os.path.abspath(''))
from src.LLM.llm import get_sentiment, get_batch_sentiment

# %%
last_processed_uid = 0
sentiment_file_path = '../../data/sentiment/news_sentiment_results.csv'
processed_news_file_path = '../../data/news/nasdaq_news_data_processed.csv'


existing_sentiment_df = pd.read_csv(sentiment_file_path)
last_processed_uid = existing_sentiment_df['UID'].max()
print(f"Initialized last_processed_uid from existing file: {last_processed_uid}")


print(f"Loading processed news data from {processed_news_file_path}...")
all_processed_news_df = pd.read_csv(processed_news_file_path, parse_dates=['Date'])
print(f"Loaded {len(all_processed_news_df)} news items.")
# Out:
# Initialized last_processed_uid from existing file: 10000
# Loading processed news data from data/news/nasdaq_news_data_processed.csv...
# Loaded 209125 news items.

# %%
def parse_news_for_llm(df_chunk: pd.DataFrame):
    required_parse_cols = ['Ticker', 'Title', 'Summary']
    news_list = df_chunk[required_parse_cols].to_dict(orient='records')
    return news_list


def analyze_sentiment_wrapper(df_chunk: pd.DataFrame, mode: str, model_name="grok-3-beta") -> pd.DataFrame:
    original_data = df_chunk[['UID', 'Date', 'Ticker']].reset_index(drop=True)

    parsed_news = parse_news_for_llm(df_chunk)

    results: List[Sentiment] = []

    if mode == 'single':
        print(f"Processing {len(parsed_news)} items in single mode using {model_name}...")
        with tqdm(total=len(parsed_news), desc="Single Processing") as pbar:
            for news_item in parsed_news:
                sentiment_result = get_sentiment(news_item, model_name)
                results.append(sentiment_result)
                pbar.update(1)

    elif mode == 'batch':
        print(f"Processing {len(parsed_news)} items in batch mode using {model_name}...")
        batch_response = get_batch_sentiment(parsed_news, model_name)
        sentiment_results = batch_response.sentiments 

        if len(sentiment_results) != len(parsed_news):
             print(f"Warning: Batch result count ({len(sentiment_results)}) doesn't match input count ({len(parsed_news)}). Alignment might be incorrect.")
        results.extend(sentiment_results[:len(parsed_news)]) 


    output_data = [{'Sentiment': r.sentiment, 'Reason': r.reason} for r in results]
    sentiment_df = pd.DataFrame(output_data)

    if sentiment_df.empty or len(sentiment_df) != len(original_data):
         print(f"Warning: Sentiment analysis resulted in {len(sentiment_df)} items, expected {len(original_data)}. Returning original data with NA sentiment.")
         final_df = original_data.copy()
         final_df['Sentiment'] = pd.NA
         final_df['Reason'] = pd.NA
    else:
        final_df = original_data.join(sentiment_df)

    return final_df[['UID', 'Date', 'Ticker', 'Sentiment', 'Reason']]

# %%
def _save_current_progress(existing_df, new_results_list, output_path, overwrite_flag):
    if not new_results_list:
        print("No new results generated yet, nothing to save.")
        return

    print("Attempting to save intermediate progress...")
    try:
        temp_new_results_df = pd.concat(new_results_list, ignore_index=True)
        temp_combined_df = pd.concat([existing_df, temp_new_results_df], ignore_index=True)

        keep_strategy = 'last' if overwrite_flag else 'first'
        initial_count = len(temp_combined_df)
        temp_combined_df.drop_duplicates(subset='UID', keep=keep_strategy, inplace=True)
        if len(temp_combined_df) < initial_count:
                print(f"(Intermediate save) Removed {initial_count - len(temp_combined_df)} duplicate UIDs (keeping '{keep_strategy}').")


        temp_combined_df.sort_values(by='UID', inplace=True)
        if 'UID' in temp_combined_df.columns:
            temp_combined_df['UID'] = temp_combined_df['UID'].astype(int)

        temp_combined_df.to_csv(output_path, index=False, date_format='%Y-%m-%d')
        print(f"Intermediate progress saved successfully to {output_path}")
    except Exception as e:
        print(f"Error saving intermediate progress: {e}")

# %%
def process_sentiment_by_uid(
    processed_news_df: pd.DataFrame,
    batch_size: int,
    start_uid: int,
    end_uid: int,
    overwrite: bool = False,
    model_name: str = "grok-3-beta",
    sentiment_output_path: str = '../../data/sentiment/news_sentiment_results.csv'
) -> None:
    global last_processed_uid

    print(f"\n--- Starting Sentiment Processing ---")
    print(f"Range: UID {start_uid} to {end_uid}")
    print(f"Batch Size: {batch_size}")
    print(f"Overwrite: {overwrite}")
    print(f"Model: {model_name}")
    print(f"Output Path: {sentiment_output_path}")

    existing_sentiment_df = pd.read_csv(sentiment_output_path, parse_dates=['Date'])
    
    # --- 1. Filter News Data Based on UID Range and Overwrite Flag ---
    target_news_df = processed_news_df[
        (processed_news_df['UID'] >= start_uid) & (processed_news_df['UID'] <= end_uid)
    ].copy()

    if target_news_df.empty:
        print(f"No news data found in the specified UID range ({start_uid}-{end_uid}). Nothing to process.")
        return # Exit if no data in range

    uids_to_process_df = pd.DataFrame() # Initialize an empty DataFrame

    if overwrite:
        print("Overwrite mode enabled. Processing all UIDs in the specified range.")
        uids_to_process_df = target_news_df
        # Filter out the existing results within the range that will be replaced
        if not existing_sentiment_df.empty:
            existing_sentiment_df = existing_sentiment_df[
                (existing_sentiment_df['UID'] < start_uid) | (existing_sentiment_df['UID'] > end_uid)
            ]
            print(f"Removed existing sentiments within UID range {start_uid}-{end_uid} due to overwrite.")
    else:
        existing_uids = set(existing_sentiment_df['UID'].unique())
        uids_to_process_df = target_news_df[~target_news_df['UID'].isin(existing_uids)]
        print(f"Found {len(target_news_df) - len(uids_to_process_df)} UIDs in range already processed. Skipping them.")


    if uids_to_process_df.empty:
        print("No new UIDs to process in the specified range")
        return

    total_to_process = len(uids_to_process_df)
    print(f"Total UIDs to process in this run: {total_to_process}")

    # --- 2. Process in Batches ---
    all_new_results = []
    num_batches = math.ceil(total_to_process / batch_size)

    for i in tqdm(range(num_batches), desc="Processing Batches"):
        start_index = i * batch_size
        end_index = min((i + 1) * batch_size, total_to_process)
        current_chunk_df = uids_to_process_df.iloc[start_index:end_index]


        print(f"\nProcessing batch {i+1}/{num_batches} (UIDs {current_chunk_df['UID'].min()} - {current_chunk_df['UID'].max()})...")

        max_retries = 2
        retries = 0
        batch_successful = False

        while retries <= max_retries and not batch_successful:
            try:
                batch_results_df = analyze_sentiment_wrapper(current_chunk_df, mode='batch', model_name=model_name)
                
                batch_successful = True
                
                all_new_results.append(batch_results_df)

                if batch_successful:
                    break

            except Exception as e:
                retries += 1
                print(f"\nexception encountered on batch {i+1} (Attempt {retries}/{max_retries + 1}). Error: {e}")
                if retries <= max_retries:
                    _save_current_progress(existing_sentiment_df, all_new_results, sentiment_output_path, overwrite)
                    wait_time = 60
                    print(f"Waiting for {wait_time} seconds before retrying...")
                    time.sleep(wait_time)
                    print(f"Retrying batch {i+1}...")
                else:
                    print(f"Max retries ({max_retries}) exceeded for batch {i+1}. Skipping this batch.")
                    break


    # --- 3. Combine, Deduplicate, and Save ---
    if not all_new_results:
        print("No new sentiment results were generated.")
        return

    print("Combining new results with existing data...")
    new_results_df = pd.concat(all_new_results, ignore_index=True)


    final_sentiment_df = pd.concat([existing_sentiment_df, new_results_df], ignore_index=True)


    # Sort by UID
    final_sentiment_df.sort_values(by='UID', inplace=True)

    # --- 4. Save Results ---
    try:
        print(f"Saving {len(final_sentiment_df)} sentiment results to {sentiment_output_path}...")
        final_sentiment_df.to_csv(sentiment_output_path, index=False, date_format='%Y-%m-%d')
        print("Save successful.")
        max_processed_in_run = new_results_df['UID'].max() if not new_results_df.empty else start_uid -1 # Fallback if nothing new processed
        new_last_processed = max(last_processed_uid, max_processed_in_run, end_uid if uids_to_process_df.empty else -1) # Ensure requested range end is considered

        if new_last_processed > last_processed_uid:
             last_processed_uid = new_last_processed
             print(f"Updated global last_processed_uid to: {last_processed_uid}")
        else:
             print(f"Global last_processed_uid remains: {last_processed_uid}")


    except Exception as e:
        print(f"Error saving results to {sentiment_output_path}: {e}")

    print(f"--- Sentiment Processing Finished ---")

# %%
process_sentiment_by_uid(
        processed_news_df=all_processed_news_df,
        batch_size=30,
        start_uid=10001,
        end_uid=20000,
        overwrite=False,
        model_name="grok-3-fast-beta",
        output_path='../../data/sentiment/news_sentiment_results.csv'
    )
print(f"\nCurrent last processed UID after run: {last_processed_uid}")
# Out:
# --- Starting Sentiment Processing ---
# Range: UID 10001 to 20000
# Batch Size: 30
# Overwrite: False
# Model: grok-3-fast-beta
# Output Path: data/sentiment/news_sentiment_results.csv
# Found 0 UIDs in range already processed. Skipping them.
# Total UIDs to process in this run: 10000
# Processing Batches:   0%|          | 0/334 [00:00<?, ?it/s]
# Processing batch 1/334 (UIDs 10001 - 10030)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 2/334 (UIDs 10031 - 10060)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 3/334 (UIDs 10061 - 10090)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 4/334 (UIDs 10091 - 10120)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 5/334 (UIDs 10121 - 10150)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 6/334 (UIDs 10151 - 10180)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 7/334 (UIDs 10181 - 10210)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 8/334 (UIDs 10211 - 10240)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 9/334 (UIDs 10241 - 10270)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 10/334 (UIDs 10271 - 10300)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 11/334 (UIDs 10301 - 10330)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 12/334 (UIDs 10331 - 10360)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 13/334 (UIDs 10361 - 10390)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 14/334 (UIDs 10391 - 10420)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 15/334 (UIDs 10421 - 10450)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 16/334 (UIDs 10451 - 10480)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 17/334 (UIDs 10481 - 10510)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 18/334 (UIDs 10511 - 10540)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 19/334 (UIDs 10541 - 10570)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 20/334 (UIDs 10571 - 10600)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 21/334 (UIDs 10601 - 10630)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 22/334 (UIDs 10631 - 10660)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 23/334 (UIDs 10661 - 10690)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 24/334 (UIDs 10691 - 10720)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 25/334 (UIDs 10721 - 10750)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 26/334 (UIDs 10751 - 10780)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 27/334 (UIDs 10781 - 10810)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 28/334 (UIDs 10811 - 10840)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 29/334 (UIDs 10841 - 10870)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 30/334 (UIDs 10871 - 10900)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 31/334 (UIDs 10901 - 10930)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 32/334 (UIDs 10931 - 10960)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 33/334 (UIDs 10961 - 10990)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 34/334 (UIDs 10991 - 11020)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 35/334 (UIDs 11021 - 11050)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 36/334 (UIDs 11051 - 11080)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 37/334 (UIDs 11081 - 11110)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 38/334 (UIDs 11111 - 11140)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 39/334 (UIDs 11141 - 11170)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 40/334 (UIDs 11171 - 11200)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 41/334 (UIDs 11201 - 11230)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 42/334 (UIDs 11231 - 11260)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 43/334 (UIDs 11261 - 11290)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 44/334 (UIDs 11291 - 11320)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 45/334 (UIDs 11321 - 11350)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 46/334 (UIDs 11351 - 11380)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 47/334 (UIDs 11381 - 11410)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 48/334 (UIDs 11411 - 11440)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 49/334 (UIDs 11441 - 11470)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 50/334 (UIDs 11471 - 11500)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 51/334 (UIDs 11501 - 11530)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 52/334 (UIDs 11531 - 11560)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 53/334 (UIDs 11561 - 11590)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 54/334 (UIDs 11591 - 11620)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 55/334 (UIDs 11621 - 11650)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 56/334 (UIDs 11651 - 11680)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 57/334 (UIDs 11681 - 11710)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 58/334 (UIDs 11711 - 11740)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 59/334 (UIDs 11741 - 11770)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 60/334 (UIDs 11771 - 11800)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 61/334 (UIDs 11801 - 11830)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 62/334 (UIDs 11831 - 11860)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 63/334 (UIDs 11861 - 11890)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 64/334 (UIDs 11891 - 11920)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 65/334 (UIDs 11921 - 11950)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 66/334 (UIDs 11951 - 11980)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 67/334 (UIDs 11981 - 12010)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 68/334 (UIDs 12011 - 12040)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 69/334 (UIDs 12041 - 12070)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 70/334 (UIDs 12071 - 12100)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 71/334 (UIDs 12101 - 12130)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 72/334 (UIDs 12131 - 12160)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 73/334 (UIDs 12161 - 12190)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 74/334 (UIDs 12191 - 12220)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 75/334 (UIDs 12221 - 12250)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 76/334 (UIDs 12251 - 12280)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 77/334 (UIDs 12281 - 12310)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 78/334 (UIDs 12311 - 12340)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 79/334 (UIDs 12341 - 12370)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 80/334 (UIDs 12371 - 12400)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 81/334 (UIDs 12401 - 12430)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 82/334 (UIDs 12431 - 12460)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 83/334 (UIDs 12461 - 12490)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 84/334 (UIDs 12491 - 12520)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 85/334 (UIDs 12521 - 12550)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 86/334 (UIDs 12551 - 12580)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 87/334 (UIDs 12581 - 12610)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 88/334 (UIDs 12611 - 12640)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 89/334 (UIDs 12641 - 12670)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 90/334 (UIDs 12671 - 12700)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 91/334 (UIDs 12701 - 12730)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 92/334 (UIDs 12731 - 12760)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 93/334 (UIDs 12761 - 12790)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 94/334 (UIDs 12791 - 12820)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 95/334 (UIDs 12821 - 12850)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 96/334 (UIDs 12851 - 12880)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 97/334 (UIDs 12881 - 12910)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 98/334 (UIDs 12911 - 12940)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 99/334 (UIDs 12941 - 12970)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 100/334 (UIDs 12971 - 13000)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 101/334 (UIDs 13001 - 13030)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 102/334 (UIDs 13031 - 13060)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 103/334 (UIDs 13061 - 13090)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 104/334 (UIDs 13091 - 13120)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 105/334 (UIDs 13121 - 13150)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 106/334 (UIDs 13151 - 13180)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 107/334 (UIDs 13181 - 13210)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 108/334 (UIDs 13211 - 13240)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 109/334 (UIDs 13241 - 13270)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 110/334 (UIDs 13271 - 13300)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 111/334 (UIDs 13301 - 13330)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 112/334 (UIDs 13331 - 13360)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 113/334 (UIDs 13361 - 13390)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 114/334 (UIDs 13391 - 13420)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 115/334 (UIDs 13421 - 13450)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 116/334 (UIDs 13451 - 13480)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 117/334 (UIDs 13481 - 13510)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 118/334 (UIDs 13511 - 13540)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 119/334 (UIDs 13541 - 13570)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 120/334 (UIDs 13571 - 13600)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 121/334 (UIDs 13601 - 13630)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 122/334 (UIDs 13631 - 13660)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 123/334 (UIDs 13661 - 13690)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 124/334 (UIDs 13691 - 13720)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 125/334 (UIDs 13721 - 13750)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 126/334 (UIDs 13751 - 13780)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 127/334 (UIDs 13781 - 13810)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 128/334 (UIDs 13811 - 13840)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 129/334 (UIDs 13841 - 13870)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 130/334 (UIDs 13871 - 13900)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 131/334 (UIDs 13901 - 13930)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 132/334 (UIDs 13931 - 13960)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 133/334 (UIDs 13961 - 13990)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 134/334 (UIDs 13991 - 14020)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 135/334 (UIDs 14021 - 14050)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 136/334 (UIDs 14051 - 14080)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 137/334 (UIDs 14081 - 14110)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 138/334 (UIDs 14111 - 14140)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 139/334 (UIDs 14141 - 14170)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 140/334 (UIDs 14171 - 14200)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 141/334 (UIDs 14201 - 14230)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 142/334 (UIDs 14231 - 14260)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 143/334 (UIDs 14261 - 14290)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 144/334 (UIDs 14291 - 14320)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 145/334 (UIDs 14321 - 14350)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 146/334 (UIDs 14351 - 14380)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 147/334 (UIDs 14381 - 14410)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 148/334 (UIDs 14411 - 14440)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 149/334 (UIDs 14441 - 14470)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 150/334 (UIDs 14471 - 14500)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 151/334 (UIDs 14501 - 14530)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 152/334 (UIDs 14531 - 14560)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 153/334 (UIDs 14561 - 14590)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 154/334 (UIDs 14591 - 14620)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 155/334 (UIDs 14621 - 14650)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 156/334 (UIDs 14651 - 14680)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 157/334 (UIDs 14681 - 14710)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 158/334 (UIDs 14711 - 14740)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 159/334 (UIDs 14741 - 14770)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 160/334 (UIDs 14771 - 14800)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 161/334 (UIDs 14801 - 14830)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 162/334 (UIDs 14831 - 14860)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 163/334 (UIDs 14861 - 14890)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 164/334 (UIDs 14891 - 14920)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 165/334 (UIDs 14921 - 14950)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 166/334 (UIDs 14951 - 14980)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 167/334 (UIDs 14981 - 15010)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 168/334 (UIDs 15011 - 15040)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 169/334 (UIDs 15041 - 15070)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 170/334 (UIDs 15071 - 15100)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 171/334 (UIDs 15101 - 15130)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 172/334 (UIDs 15131 - 15160)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 173/334 (UIDs 15161 - 15190)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 174/334 (UIDs 15191 - 15220)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 175/334 (UIDs 15221 - 15250)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 176/334 (UIDs 15251 - 15280)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 177/334 (UIDs 15281 - 15310)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 178/334 (UIDs 15311 - 15340)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 179/334 (UIDs 15341 - 15370)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 180/334 (UIDs 15371 - 15400)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 181/334 (UIDs 15401 - 15430)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 182/334 (UIDs 15431 - 15460)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 183/334 (UIDs 15461 - 15490)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 184/334 (UIDs 15491 - 15520)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 185/334 (UIDs 15521 - 15550)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 186/334 (UIDs 15551 - 15580)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 187/334 (UIDs 15581 - 15610)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 188/334 (UIDs 15611 - 15640)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 189/334 (UIDs 15641 - 15670)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 190/334 (UIDs 15671 - 15700)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 191/334 (UIDs 15701 - 15730)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 192/334 (UIDs 15731 - 15760)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 193/334 (UIDs 15761 - 15790)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 194/334 (UIDs 15791 - 15820)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 195/334 (UIDs 15821 - 15850)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 196/334 (UIDs 15851 - 15880)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 197/334 (UIDs 15881 - 15910)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 198/334 (UIDs 15911 - 15940)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 199/334 (UIDs 15941 - 15970)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 200/334 (UIDs 15971 - 16000)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 201/334 (UIDs 16001 - 16030)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 202/334 (UIDs 16031 - 16060)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 203/334 (UIDs 16061 - 16090)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 204/334 (UIDs 16091 - 16120)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 205/334 (UIDs 16121 - 16150)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 206/334 (UIDs 16151 - 16180)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 207/334 (UIDs 16181 - 16210)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 208/334 (UIDs 16211 - 16240)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 209/334 (UIDs 16241 - 16270)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 210/334 (UIDs 16271 - 16300)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 211/334 (UIDs 16301 - 16330)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 212/334 (UIDs 16331 - 16360)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 213/334 (UIDs 16361 - 16390)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 214/334 (UIDs 16391 - 16420)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 215/334 (UIDs 16421 - 16450)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 216/334 (UIDs 16451 - 16480)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 217/334 (UIDs 16481 - 16510)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 218/334 (UIDs 16511 - 16540)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 219/334 (UIDs 16541 - 16570)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 220/334 (UIDs 16571 - 16600)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 221/334 (UIDs 16601 - 16630)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 222/334 (UIDs 16631 - 16660)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 223/334 (UIDs 16661 - 16690)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 224/334 (UIDs 16691 - 16720)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 225/334 (UIDs 16721 - 16750)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 226/334 (UIDs 16751 - 16780)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 227/334 (UIDs 16781 - 16810)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 228/334 (UIDs 16811 - 16840)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 229/334 (UIDs 16841 - 16870)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 230/334 (UIDs 16871 - 16900)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 231/334 (UIDs 16901 - 16930)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 232/334 (UIDs 16931 - 16960)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 233/334 (UIDs 16961 - 16990)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 234/334 (UIDs 16991 - 17020)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 235/334 (UIDs 17021 - 17050)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 236/334 (UIDs 17051 - 17080)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 237/334 (UIDs 17081 - 17110)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 238/334 (UIDs 17111 - 17140)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 239/334 (UIDs 17141 - 17170)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 240/334 (UIDs 17171 - 17200)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 241/334 (UIDs 17201 - 17230)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 242/334 (UIDs 17231 - 17260)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 243/334 (UIDs 17261 - 17290)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 244/334 (UIDs 17291 - 17320)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 245/334 (UIDs 17321 - 17350)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 246/334 (UIDs 17351 - 17380)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 247/334 (UIDs 17381 - 17410)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 248/334 (UIDs 17411 - 17440)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 249/334 (UIDs 17441 - 17470)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 250/334 (UIDs 17471 - 17500)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 251/334 (UIDs 17501 - 17530)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 252/334 (UIDs 17531 - 17560)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 253/334 (UIDs 17561 - 17590)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 254/334 (UIDs 17591 - 17620)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 255/334 (UIDs 17621 - 17650)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 256/334 (UIDs 17651 - 17680)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# exception encountered on batch 256 (Attempt 1/3). Error: 'NoneType' object has no attribute 'sentiments'
# Attempting to save intermediate progress...
# Intermediate progress saved successfully to data/sentiment/news_sentiment_results.csv
# Waiting for 60 seconds before retrying...
# Retrying batch 256...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# exception encountered on batch 256 (Attempt 2/3). Error: Error code: 503 - {'code': 'The service is currently unavailable', 'error': 'The model is temporarily unavailable.'}
# Attempting to save intermediate progress...
# Intermediate progress saved successfully to data/sentiment/news_sentiment_results.csv
# Waiting for 60 seconds before retrying...
# Retrying batch 256...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 257/334 (UIDs 17681 - 17710)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 258/334 (UIDs 17711 - 17740)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 259/334 (UIDs 17741 - 17770)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 260/334 (UIDs 17771 - 17800)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 261/334 (UIDs 17801 - 17830)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 262/334 (UIDs 17831 - 17860)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 263/334 (UIDs 17861 - 17890)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 264/334 (UIDs 17891 - 17920)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 265/334 (UIDs 17921 - 17950)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 266/334 (UIDs 17951 - 17980)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 267/334 (UIDs 17981 - 18010)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 268/334 (UIDs 18011 - 18040)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 269/334 (UIDs 18041 - 18070)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 270/334 (UIDs 18071 - 18100)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 271/334 (UIDs 18101 - 18130)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 272/334 (UIDs 18131 - 18160)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 273/334 (UIDs 18161 - 18190)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 274/334 (UIDs 18191 - 18220)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 275/334 (UIDs 18221 - 18250)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 276/334 (UIDs 18251 - 18280)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 277/334 (UIDs 18281 - 18310)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 278/334 (UIDs 18311 - 18340)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 279/334 (UIDs 18341 - 18370)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 280/334 (UIDs 18371 - 18400)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 281/334 (UIDs 18401 - 18430)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 282/334 (UIDs 18431 - 18460)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 283/334 (UIDs 18461 - 18490)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 284/334 (UIDs 18491 - 18520)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 285/334 (UIDs 18521 - 18550)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 286/334 (UIDs 18551 - 18580)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 287/334 (UIDs 18581 - 18610)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 288/334 (UIDs 18611 - 18640)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 289/334 (UIDs 18641 - 18670)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 290/334 (UIDs 18671 - 18700)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 291/334 (UIDs 18701 - 18730)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 292/334 (UIDs 18731 - 18760)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 293/334 (UIDs 18761 - 18790)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 294/334 (UIDs 18791 - 18820)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 295/334 (UIDs 18821 - 18850)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 296/334 (UIDs 18851 - 18880)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 297/334 (UIDs 18881 - 18910)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 298/334 (UIDs 18911 - 18940)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 299/334 (UIDs 18941 - 18970)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 300/334 (UIDs 18971 - 19000)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 301/334 (UIDs 19001 - 19030)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 302/334 (UIDs 19031 - 19060)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 303/334 (UIDs 19061 - 19090)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 304/334 (UIDs 19091 - 19120)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 305/334 (UIDs 19121 - 19150)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 306/334 (UIDs 19151 - 19180)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 307/334 (UIDs 19181 - 19210)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 308/334 (UIDs 19211 - 19240)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 309/334 (UIDs 19241 - 19270)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 310/334 (UIDs 19271 - 19300)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 311/334 (UIDs 19301 - 19330)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 312/334 (UIDs 19331 - 19360)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 313/334 (UIDs 19361 - 19390)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 314/334 (UIDs 19391 - 19420)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 315/334 (UIDs 19421 - 19450)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 316/334 (UIDs 19451 - 19480)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 317/334 (UIDs 19481 - 19510)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 318/334 (UIDs 19511 - 19540)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 319/334 (UIDs 19541 - 19570)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 320/334 (UIDs 19571 - 19600)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 321/334 (UIDs 19601 - 19630)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 322/334 (UIDs 19631 - 19660)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 323/334 (UIDs 19661 - 19690)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 324/334 (UIDs 19691 - 19720)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 325/334 (UIDs 19721 - 19750)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 326/334 (UIDs 19751 - 19780)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 327/334 (UIDs 19781 - 19810)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 328/334 (UIDs 19811 - 19840)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 329/334 (UIDs 19841 - 19870)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 330/334 (UIDs 19871 - 19900)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 331/334 (UIDs 19901 - 19930)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 332/334 (UIDs 19931 - 19960)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 333/334 (UIDs 19961 - 19990)...
# Processing 30 items in batch mode using grok-3-fast-beta...
#
# Processing batch 334/334 (UIDs 19991 - 20000)...
# Processing 10 items in batch mode using grok-3-fast-beta...
# Combining new results with existing data...
# Saving 20000 sentiment results to data/sentiment/news_sentiment_results.csv...
# Save successful.
# Updated global last_processed_uid to: 20000
# --- Sentiment Processing Finished ---
#
# Current last processed UID after run: 20000

# %%
sentiment_df = pd.read_csv(sentiment_file_path, parse_dates=['Date'])
sentiment_df.tail(10)
# Out:
#          UID       Date Ticker         Sentiment  \
# 19990  19991 2016-11-21   BIDU  Slightly Bullish
# 19991  19992 2016-11-21   TSCO           Bullish
# 19992  19993 2016-11-22    TXN           Bullish
# 19993  19994 2016-11-22   ROST           Neutral
# 19994  19995 2016-11-22   COST           Neutral
# 19995  19996 2016-11-22    ADI           Neutral
# 19996  19997 2016-11-22    ADI  Slightly Bullish
# 19997  19998 2016-11-22    ADI           Bullish
# 19998  19999 2016-11-22    ADI  Strongly Bullish
# 19999  20000 2016-11-22    ADI  Strongly Bullish
#
#                                                   Reason
# 19990  The summary mentions Baidu, Inc. is up about 1...
# 19991  Tractor Supply Company raised its share buybac...
# 19992  Texas Instruments Inc. has a Zacks Rank #2 (Bu...
# 19993  The news item mentions Ross Stores, Inc. in pa...
# 19994  The summary discusses Costco's Black Friday de...
# 19995  The summary focuses on historical earnings rea...
# 19996  Analog Devices, Inc. reported earnings that co...
# 19997  Analog Devices, Inc. is trading up 6.0% on the...
# 19998  Analog Devices, Inc. reported Q4 earnings of $...
# 19999  Analog Devices, Inc. reported better-than-expe...
